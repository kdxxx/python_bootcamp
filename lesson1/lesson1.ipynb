# %%
print('hello');
# Out:
# hello

# %%
help> keywords
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7bb10b3b0f8a> in <module>()
# ----> 1 help> keywords
#
# NameError: name 'keywords' is not defined

# %% [markdown]
# this is a test

# %%
help()
# Out:
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# interpreter, you can type "help(object)".  Executing "help('string')"
# has the same effect as typing a particular string at the help> prompt.

# %%
fav_num = 12
if fav_num <24:
  print('my favorite is less than 24')
# Out:
# my favorite is less than 24

# %% [markdown]
# snake_case =>
# get_user_email

# %%
# for commenting 

def greeting(name):
  print('hello '+name)
greeting('deniz')
# Out:
# hello deniz

# %%
"""Triple commentss"""

# %%
name = 'deniz'
age = 23
print(type(name))
print(type(age))
type(name)
# Out:
# <class 'str'>
# <class 'int'>
# str

# %%
store_items= [ 'apple', 1.49, 'banana',3.7,'cheese',4.2]
print(store_items,type(store_items))
print(store_items[2])
print(store_items[0])
# Out:
# ['apple', 1.49, 'banana', 3.7, 'cheese', 4.2] <class 'list'>
# banana
# apple

# %%
print(store_items[0:4])
print(store_items[2:])
print(store_items[:4])
# Out:
# ['apple', 1.49, 'banana', 3.7]
# ['banana', 3.7, 'cheese', 4.2]
# ['apple', 1.49, 'banana', 3.7]

# %%
store_items[2] = 'chocolate'
print(store_items)
# Out:
# ['apple', 1.49, 'chocolate', 3.7, 'cheese', 4.2]

# %% [markdown]
# type conversion

# %%
age = 25
print(type(age))
age = age + 4.3
print(age)
print(type(age))
# Out:
# <class 'int'>
# 29.3
# <class 'float'>

# %%
age = '23'
type(age)
age = int(age)
age = age + 3
print(age)
# Out:
# 26

# %% [markdown]
# input and output functions

# %%
print( 'hi, this is an output function')
# Out:
# hi, this is an output function

# %%
name = 'deniz'
print(name)
print('PS: this is an input function')
# Out:
# deniz
# PS: this is an input function

# %%
name = 'tuğçe'
print('hello ',name)
# Out:
# hello  tuğçe

# %%
name = input('name: ')
print('greetings from ',name)
# Out:
# name: tuğçe
# greetings from  tuğçe

# %%
number = input('number: ')
print(int(number)+10)
# Out:
# number: 10
# 20

# %%
import math

# %%
floor_number = (math.floor(3.4))
print(floor_number,type(floor_number))
# Out:
# 3 <class 'int'>

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2022-06-30 14:05:22.422426

# %%
import random 
print(random.randint(1,6))
# Out:
# 5

# %%
print(5+2)
print(5*2)
print(5-2)
print(5/2)
print(5//2)
print(5**2)
print(5%2)
# Out:
# 7
# 10
# 3
# 2.5
# 2
# 25
# 1

# %%
x= 5
x+= 5
print(x)
# Out:
# 10

# %%
x = 1
y = 2
print(x<y)
print(x>y)
print(x<=y)
print(x>=y)
print(x==y)
print(x!=y)
# Out:
# True
# False
# True
# False
# False
# True

# %%
print(True and False)
print(True and True)
# Out:
# False
# True

# %%
print(True or False)
print(False or False)
# Out:
# True
# False

# %%
print(not False)
# Out:
# True
