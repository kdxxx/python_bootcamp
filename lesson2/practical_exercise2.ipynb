# %% [markdown]
# # Practical exercise 2:  You are a game developer :)
#
# In this practical exercise you are a game developer. You will program your first game – Rock, Paper, Scissors.
#
# If you are not familiar with the game, you can read about it here: https://en.wikipedia.org/wiki/Rock_paper_scissors.
#
# You will program the game step by step. Please read the instructions carefully. There are hints and important explanations that will help you with this exercise.

# %% [markdown]
# ##Warm up
#
# Each player can choose between the three actions "rock", "paper" and "scissors". First, you need to create a list that contains all possible actions.

# %%
#Please create a list containing the three actions of the game.
actions = ['rock','paper','scissors']

# %% [markdown]
# # Choose an action
#
# Now you have the list with the actions ready. The next step is to let Python randomly choose an action from this list. Each player has to make a choice, so Python has to make a choice for player 1 and another one for player 2.
#
# 📌The built-in module "random" can help you with this. As you might remember from previous lessons you can use the .randint() method to generate random numbers.
#
# 📌📌There is another method in the random module called .choice(). It takes a list as input and selects an item randomly from that list.

# %%
#Import the random library
import random

#Select a random action for each player
player1_action = actions[random.randint(0,2)]
player2_action = random.choice(actions)

#Use the print function to print the players choices
print(player1_action)
print(player2_action)
# Out:
# paper
# paper

# %% [markdown]
# # Determine the winner
#
# So, who won? To determine the winner, you first have to specify all possible outcomes of the game. Then you can use conditional statements to specify which outcome will lead to a win for player 1 or player 2, or a tie.
#
# First, let's start with the outcome that both users chose the same action: a tie!
# In case of a tie, the game should print the message "Tie! Both players chose the same action." to the screen.
#
# 📌Use conditional statements to check whether the players actions are equal to each other and *if* this condition is true the message should be printed.

# %%
#1 - Tie Condition
#Please write an if statement to check if the players chose the same action
if player1_action == player2_action:
  print('tie, again')
# Out:
# tie, again

# %% [markdown]
# Now, let's focus on the remaining outcomes. We have three different actions: rock, paper and scissors.
#
# This is a list of all the possible combinations (without those that result in a tie):
#
# 1.   (paper, rock)
# 2.   (paper, scissors)
# 3.   (scissors, rock)
# 4.   (scissors, paper)
# 5.   (rock, paper)
# 6.   (rock, scissors)
#
# You need to check all these conditions in order to determine the winner.
#
# 📌You can use the "and" operator to combine two actions in one conditional statement.
#
# 📌📌Another approach is using nested if statements to check whether the action of player 2 beats the action of player 1.
#
# 🧨💣In the cell, first copy the code you wrote for "Tie" conditions. Then continue to add the other outcomes using "elif".

# %%
#Copy your code of the tie-conditions here
#1 - Tie Condition
if player1_action == player2_action:
  print('tie, again')

#2-Winning Conditions
#Please add the conditional statements for the remaining combinations 
elif player1_action == 'paper':
  if player2_action == 'rock':
    print('player1 is winner')
  else:
    print('player2 is winner')
elif player1_action == 'rock':
  if player2_action == 'paper':
    print("Winner is: Player 2")
  else:
    print("Winner is: Player 1")

elif player1_action == 'scissors':
  if player2_action == 'paper':
    print("Winner is: Player 1")
  else:
    print("Winner is: Player 2")
# Out:
# tie, again

# %% [markdown]
# # Best of 3 or 5 or single round ? :)
#
# Now that you have your game set, let's also ask the users how many rounds they want to play.
#
# 📌 You can use the input function for this.
#
# And because there are multiple rounds, you need to keep track of the score. For this, you need to create a variable for each player that is 0 in the beginning.

# %%
#Please ask the user how many rounds they want to play
round = input('how many rounds do you want to play?')

#Scores of players

player1_score = 0
player2_score = 0

# %% [markdown]
# # Use a for loop to specify the number of rounds
# The user specified how many rounds he or she wants to play.
#
# One way to use this information is to put the game inside of a for loop.
#
# 📌 You can use a for loop and the range() function to repeat the loop for a specified number of times.
#
# 📌📌 Don't forget to convert the user input to the data type integer. You can use the int() function for this.
#
# 📌📌📌 Don't forget to increment or add 1 to the score of the players that win, and print the current score after each round. You can use the assignment operator +=1 for this.

# %%
#Collect all the components of your program to run it in a for loop
#Import the random library
import random

#Add the code to create a list containing the three actions of the game.
action_list= ['rock','paper','scissors']

#Add the code to set the scores of players to 0
player1_score = 0
player2_score = 0

#Add the code to ask the user how many rounds they want to play
total_round = input('how many rounds would you like to play')

#Write a for loop and put the game inside
for i in range(int(total_round)):


  #Add the code to select a random action for each player
  player1_choice = random.choice(action_list)
  player2_choice = action_list[random.randint(0,2)]

  #Add the code to print the players choices
  print('player1: ',player1_choice)
  print('player2: ',player2_choice)

  #Add the tie condition
  if player1_choice == player2_choice:
    print('tie...')

  #Add the remaining condition
  elif player1_choice == 'paper':
    if player2_choice == 'rock':
      print('player1 is winner')
      player1_score += 1
    else: 
      print('player2 is winner')
      player2_score += 1

  elif player1_choice == 'rock':
    if player2_choice == 'paper':
      print('player2 is winner')
      player2_score += 1
    else: 
      print('player1 is winner')
      player1_score += 1

  elif player1_choice == 'scissors':
    if player2_choice == 'paper':
      print('player1 is winner')
      player1_score += 1
    else: 
      print('player2 is winner')
      player2_score += 1

  #print the score
  print('player1_score : ', player1_score, ' player2_score: ',player2_score)

if(player1_score> player2_score):
  print('player1 is the winner')
elif(player2_score> player1_score):
  print('player2 is the winner')
else:
  print('tie...')
# Out:
# how many rounds would you like to play5
# player1:  scissors
# player2:  rock
# player2 is winner
# player1_score :  0  player2_score:  1
# player1:  scissors
# player2:  paper
# player1 is winner
# player1_score :  1  player2_score:  1
# player1:  paper
# player2:  paper
# tie...
# player1_score :  1  player2_score:  1
# player1:  rock
# player2:  paper
# player2 is winner
# player1_score :  1  player2_score:  2
# player1:  paper
# player2:  paper
# tie...
# player1_score :  1  player2_score:  2
# player2 is the winner

# %% [markdown]
# # Use a while loop to specify the number of rounds - Part 1
#
# In this module we also learned about while loops. Another way to play the game over and over again is using a while loop.
#
# This time, let's put the game inside a while loop.
#
# 📌 You can directly use the value *True* to specify that the while loop should be executed.
#
# 💣 By the way: Another very common name for True/False values is "**Boolean values**" or "**Bools**" in short.
#
# 🧨🧨 Caution! Since we run the game in an while loop, you have to stop the game manually. Otherwise it will run infinitely.

# %%
#Collect all the components of your program to run it in a while loop
#Import the random library
import random

#Add the code to create a list containing the three actions of the game.
action_list =  ['rock','paper','scissors']

#Add the code to set the scores of players to 0
player1_score = 0
player2_score = 0

#Write a while loop and put the game inside
while True:

  #Add the code to select a random action for each player
  player1_choice = random.choice(action_list)
  player2_choice = action_list[random.randint(0,2)]

  #Add the code to print the players choices
  print('player1: ',player1_choice)
  print('player2: ',player2_choice)

  #Add the tie condition
  if player1_choice == player2_choice:
    print('tie...')

  #Add the remaining condition
  elif player1_choice == 'paper':
    if player2_choice == 'rock':
      print('player1 is winner')
      player1_score += 1
    else: 
      print('player2 is winner')
      player2_score += 1

  elif player1_choice == 'rock':
    if player2_choice == 'paper':
      print('player2 is winner')
      player2_score += 1
    else: 
      print('player1 is winner')
      player1_score += 1

  elif player1_choice == 'scissors':
    if player2_choice == 'paper':
      print('player1 is winner')
      player1_score += 1
    else: 
      print('player2 is winner')
      player2_score += 1

  #print the score
  print('player1: ',player1_score, ' player2: ',player2_score)
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# player1:  paper
# player2:  rock
# player1 is winner
# player1:  7994  player2:  7837
# player1:  scissors
# player2:  scissors
# tie...
# player1:  7994  player2:  7837
# player1:  scissors
# player2:  rock
# player2 is winner
# player1:  7994  player2:  7838
# player1:  scissors
# player2:  rock
# player2 is winner
# player1:  7994  player2:  7839
# player1:  paper
# player2:  scissors
# player2 is winner
# player1:  7994  player2:  7840
# player1:  rock
# player2:  paper
# player2 is winner
# player1:  7994  player2:  7841
# player1:  paper
# player2:  rock
# player1 is winner
# player1:  7995  player2:  7841
# player1:  paper
# player2:  scissors
# player2 is winner
# player1:  7995  player2:  7842
# player1:  rock
# player2:  scissors
# player1 is winner
# player1:  7996  player2:  7842
# player1:  rock
# player2:  paper
# player2 is winner
# player1:  7996  player2:  7843
# player1:  scissors
# player2:  paper
# player1 is winner
# player1:  7997  player2:  7843
# player1:  paper
# player2:  rock
# player1 is winner
# player1:  7998  player2:  7843
# player1:  rock
# player2:  rock
# tie...
# player1:  7998  player2:  7843
# player1:  paper
# player2:  rock
# player1 is winner
# player1:  7999  player2:  7843
# player1:  rock
# player2:  scissors
# player1 is winner
# player1:  8000  player2:  7843
# player1:  paper
# player2:  scissors
# player2 is winner
# player1:  8000  player2:  7844
# player1:  scissors
# player2:  rock
# player2 is winner
# player1:  8000  player2:  7845
# player1:  scissors
# player2:  rock
# player2 is winner
# player1:  8000  player2:  7846
# player1:  rock
# player2:  scissors
# player1 is winner
# player1:  8001  player2:  7846
# player1:  paper
# player2:  paper
# tie...
# player1:  8001  player2:  7846
# player1:  paper
# player2:  paper
# tie...
# player1:  8001  player2:  7846
# player1:  scissors
# player2:  rock
# player2 is winner
# player1:  8001  player2:  7847
# player1:  paper
# player2:  scissors
# player2 is winner
# player1:  8001  player2:  7848
# player1:  rock
# player2:  scissors
# player1 is winner
# player1:  8002  player2:  7848
# player1:  scissors
# player2:  rock
# player2 is winner
# player1:  8002  player2:  7849
# player1:  scissors
# player2:  rock
# player2 is winner
# player1:  8002  player2:  7850
# player1:  rock
# player2:  rock
# tie...
# player1:  8002  player2:  7850
# player1:  scissors
# player2:  paper
# player1 is winner
# player1:  8003  player2:  7850
# player1:  scissors
# player2:  paper
# player1 is winner
# player1:  8004  player2:  7850
# player1:  scissors
# player2:  paper
# player1 is winner
# player1:  8005  player2:  7850
# player1:  scissors
# player2:  paper
# player1 is winner
# player1:  8006  player2:  7850
# player1:  scissors
# player2:  rock
# player2 is winner
# player1:  8006  player2:  7851
# player1:  paper
# player2:  paper
# tie...
# player1:  8006  player2:  7851
# player1:  rock
# player2:  rock
# tie...
# player1:  8006  player2:  7851
# player1:  paper
# player2:  paper
# tie...
# player1:  8006  player2:  7851
# player1:  rock
# player2:  paper
# player2 is winner
# player1:  8006  player2:  7852
# player1:  paper
# player2:  paper
# tie...
# player1:  8006  player2:  7852
# player1:  rock
# player2:  paper
# player2 is winner
# player1:  8006  player2:  7853
# player1:  paper
# player2:  rock
# player1 is winner
# player1:  8007  player2:  7853
# player1:  paper
# player2:  paper
# tie...
# player1:  8007  player2:  7853
# player1:  scissors
# player2:  scissors
# tie...
# player1:  8007  player2:  7853
# player1:  rock
# player2:  paper
# player2 is winner
# player1:  8007  player2:  7854
# player1:  rock
# player2:  paper
# player2 is winner
# player1:  8007  player2:  7855
# player1:  scissors
# player2:  scissors
# tie...
# player1:  8007  player2:  7855
# player1:  rock
# player2:  paper
# player2 is winner
# player1:  8007  player2:  7856
# player1:  rock
# player2:  paper
# player2 is winner
# player1:  8007  player2:  7857
# player1:  rock
# player2:  paper
# player2 is winner
# player1:  8007  player2:  7858
# player1:  paper
# player2:  paper
# tie...
# player1:  8007  player2:  7858
# player1:  rock
# player2:  rock
# tie...
# player1:  8007  player2:  7858
# player1:  paper
# player2:  rock
# player1 is winner
# player1:  8008  player2:  7858
# player1:  paper
# player2:  paper
# tie...
# player1:  8008  player2:  7858
# player1:  paper
# player2:  scissors
# player2 is winner
# player1:  8008  player2:  7859
# player1:  paper
# player2:  scissors
# player2 is winner
# player1:  8008  player2:  7860
# player1:  scissors
# player2:  paper
# player1 is winner
# player1:  8009  player2:  7860
# player1:  rock
# player2:  rock
# tie...
# player1:  8009  player2:  7860
# player1:  scissors
# player2:  rock
# player2 is winner
# player1:  8009  player2:  7861
# player1:  paper
# player2:  rock
# player1 is winner
# player1:  8010  player2:  7861
# player1:  scissors
# player2:  paper
# player1 is winner
# player1:  8011  player2:  7861
# player1:  scissors
# player2:  paper
# player1 is winner
# player1:  8012  player2:  7861
# player1:  scissors
# player2:  paper
# player1 is winner
# player1:  8013  player2:  7861
# player1:  paper
# player2:  rock
# player1 is winner
# player1:  8014  player2:  7861
# player1:  scissors
# player2:  rock
# player2 is winner
# player1:  8014  player2:  7862
# player1:  paper
# player2:  rock
# player1 is winner
# player1:  8015  player2:  7862
# player1:  paper
# player2:  paper
# tie...
# player1:  8015  player2:  7862
# player1:  rock
# player2:  paper
# player2 is winner
# player1:  8015  player2:  7863
# player1:  rock
# player2:  paper
# player2 is winner
# player1:  8015  player2:  7864
# player1:  paper
# player2:  rock
# player1 is winner
# player1:  8016  player2:  7864
# player1:  paper
# player2:  scissors
# player2 is winner
# player1:  8016  player2:  7865
# player1:  paper
# player2:  rock
# player1 is winner
# player1:  8017  player2:  7865
# player1:  rock
# player2:  paper
# player2 is winner
# player1:  8017  player2:  7866
# player1:  scissors
# player2:  scissors
# tie...
# player1:  8017  player2:  7866
# player1:  paper
# player2:  paper
# tie...
# player1:  8017  player2:  7866
# player1:  rock
# player2:  scissors
# player1 is winner
# player1:  8018  player2:  7866
# player1:  paper
# player2:  rock
# player1 is winner
# player1:  8019  player2:  7866
# player1:  rock
# player2:  paper
# player2 is winner
# player1:  8019  player2:  7867
# player1:  paper
# player2:  paper
# tie...
# player1:  8019  player2:  7867
# player1:  scissors
# player2:  scissors
# tie...
# player1:  8019  player2:  7867
# player1:  paper
# player2:  scissors
# player2 is winner
# player1:  8019  player2:  7868
# player1:  scissors
# player2:  paper
# player1 is winner
# player1:  8020  player2:  7868
# player1:  rock
# player2:  paper
# player2 is winner
# player1:  8020  player2:  7869
# player1:  scissors
# player2:  paper
# player1 is winner
# player1:  8021  player2:  7869
# player1:  paper
# player2:  scissors
# player2 is winner
# player1:  8021  player2:  7870
# player1:  rock
# player2:  rock
# tie...
# player1:  8021  player2:  7870
# player1:  scissors
# player2:  rock
# player2 is winner
# player1:  8021  player2:  7871
# player1:  scissors
# player2:  rock
# player2 is winner
# player1:  8021  player2:  7872
# player1:  rock
# player2:  scissors
# player1 is winner
# player1:  8022  player2:  7872
# player1:  scissors
# player2:  paper
# player1 is winner
# player1:  8023  player2:  7872
# player1:  scissors
# player2:  paper
# player1 is winner
# player1:  8024  player2:  7872
# player1:  paper
# player2:  scissors
# player2 is winner
# player1:  8024  player2:  7873
# player1:  rock
# player2:  scissors
# player1 is winner
# player1:  8025  player2:  7873
# player1:  rock
# player2:  rock
# tie...
# player1:  8025  player2:  7873
# player1:  paper
# player2:  rock
# player1 is winner
# player1:  8026  player2:  7873
# player1:  scissors
# player2:  rock
# player2 is winner
# player1:  8026  player2:  7874
# player1:  scissors
# player2:  rock
# player2 is winner
# player1:  8026  player2:  7875
# player1:  paper
# player2:  paper
# tie...
# player1:  8026  player2:  7875
# player1:  rock
# player2:  rock
# tie...
# player1:  8026  player2:  7875
# player1:  paper
# player2:  scissors
# player2 is winner
# player1:  8026  player2:  7876
# player1:  rock
# player2:  rock
# tie...
# player1:  8026  player2:  7876
# player1:  scissors
# player2:  paper
# player1 is winner
# player1:  8027  player2:  7876
# player1:  scissors
# player2:  scissors
# tie...
# player1:  8027  player2:  7876
# player1:  paper
# player2:  scissors
# player2 is winner
# player1:  8027  player2:  7877
# player1:  rock
# player2:  scissors
# player1 is winner
# player1:  8028  player2:  7877
# player1:  scissors
# player2:  scissors
# tie...
# player1:  8028  player2:  7877
# player1:  scissors
# player2:  paper
# player1 is winner
# player1:  8029  player2:  7877
# player1:  scissors
# player2:  scissors
# tie...
# player1:  8029  player2:  7877
# player1:  paper
# player2:  scissors
# player2 is winner
# player1:  8029  player2:  7878
# player1:  scissors
# player2:  scissors
# tie...
# player1:  8029  player2:  7878
# player1:  rock
# player2:  paper
# player2 is winner
# player1:  8029  player2:  7879
# player1:  paper
# player2:  scissors
# player2 is winner
# player1:  8029  player2:  7880
# player1:  rock
# player2:  rock
# tie...
# player1:  8029  player2:  7880
# player1:  paper
# player2:  rock
# player1 is winner
# player1:  8030  player2:  7880
# player1:  rock
# player2:  scissors
# player1 is winner
# player1:  8031  player2:  7880
# player1:  paper
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-5a5e46849c4d> in <module>()
#      18
#      19   #Add the code to print the players choices
# ---> 20   print('player1: ',player1_choice)
#      21   print('player2: ',player2_choice)
#      22
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# # Use a while loop to specify the number of rounds - Part 2
#
# Now the game runs infinitely and the user can end it manually. But there is a more efficient way to do this: Let's ask the user again how many rounds they want to play, just as you did for the game inside the for loop.
#
# To prevent an infinite loop, you need to add a round_counter that is 0 at the beginning. In each round, this counter needs to increase by 1.
#
# At the end of your while loop, you need to add an "if" condition to check whether the round_counter is equal to the number of rounds that we got from user as an input. If this is the case, we need to use "**break**" to end the game.
#
# Once we end the game, it would be nice to see a message that prints the winner to the screen. In case of a tie, it should print a message that the game ended in a tie.
#
# 📌 You can use "if" and "elif" statements to determine the winner at the end.

# %%
#Collect all the components of your program to run it in a while loop
#Import the random library
import random

#Add the code to create a list containing the three actions of the game.
action_list = ['rock','paper','scissors']

#Add the code to set the scores of players to 0
player1_score = 0
player2_score = 0

#Add a round_counter that is 0 at the beginning
round_counter = 0

#Add the code to ask the user how many rounds they want to play
total_round = input('how many rounds would you like to play')

#Write a while loop and put the game inside
while True:

  #increase round_counter by 1 and print it
  round_counter +=1
  print('round: ',round_counter)

  #Add the code to select a random action for each player
  player1_choice = random.choice(action_list)
  player2_choice = action_list[random.randint(0,2)]

  #Add the code to print the players choices
  print('player1: ',player1_choice)
  print('player2: ',player2_choice)

  #Add the tie condition
  if player1_choice == player2_choice:
    print('tie...')

  #Add the remaining condition
  elif player1_choice == 'paper':
    if player2_choice == 'rock':
      print("player1 is winner")
      player1_score +=1
    else:
      print("player2 is winner")
      player2_score +=1

  elif player1_choice == 'rock':
    if player2_choice == 'paper':
      print("player2 is winner")
      player2_score +=1
    else:
      print("player1 is winner")
      player1_score +=1

  elif player1_choice == 'scissors':
    if player2_choice == 'paper':
      print("player1 is winner")
      player1_score +=1
    else:
      print("player2 is winner")
      player2_score +=1

  #print the score
  print('player1: ',player1_score,' player2: ',player2_score)

  #stop the while loop if the round_counter equals the number of total rounds
  if round_counter == int(total_round):
    break
#Print the outcome of the game by using conditional statements
if player1_score == player2_score:
  print('tie...')
elif player1_score > player2_score:
  print('player1 is the winner')
else:
  print('player2 is the winner')
# Out:
# how many rounds would you like to play3
# round:  1
# player1:  scissors
# player2:  scissors
# tie...
# player1:  0  player2:  0
# round:  2
# player1:  scissors
# player2:  rock
# player2 is winner
# player1:  0  player2:  1
# round:  3
# player1:  rock
# player2:  rock
# tie...
# player1:  0  player2:  1
# player2 is the winner
